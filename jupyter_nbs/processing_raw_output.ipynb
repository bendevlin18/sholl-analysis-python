# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('raw_output.csv', index_col = 0)

# %%
df_final = df.copy()

for idx, series in df.iterrows():
    
    ## using the number of periods in each cell to calculate how many points there were, then dividing by two
    for i in range(len(df.columns)):
        df_final.loc[idx][i] = (len(df.loc[idx][i].split('.')) - 1) / 2

# %%
df_final
# Out:
#                                                        5    25    45    65  \
# C1-MD1rIba1-2_9_3_2.28MIP_Simple Segmentation-1...  11.0  26.0  29.0  51.0
# C1-MD1rIba1-2_9_1_2.52MIP_Simple Segmentation-1...  12.0  18.0  17.0  28.0
# .DS_Store                                           12.0  18.0  17.0  28.0
# C1-MD1rIba1-2_7_4_2.28MIP_Simple Segmentation-1...  11.0  36.0  21.0  20.0
# C1-MD1rIba1-2_15_2_2.28MIP_Simple Segmentation-...  10.0   8.0  23.0  25.0
# C1-MD1rIba1-2_5_3_2.28MIP_Simple Segmentation-1...   8.0   9.0   8.0  52.0
# C1-MD1rIba1-2_5_4_2.28MIP_Simple Segmentation-2...   9.0   8.0  24.0  33.0
# C1-MD1rIba1-2_26_4_2.28MIP_Simple Segmentation-...  11.0  28.0  30.0  58.0
# C1-MD1rIba1-2_5_2_2.52-2.28MIP_Simple Segmentat...  17.0  19.0  19.0  36.0
# C1-MD1rIba1-2_10_2_2.28MIP_Simple Segmentation-...  11.0  21.0  23.0  25.0
# C1-MD1rIba1-2_2_4_2.28MIP_Simple Segmentation-1...  12.0  20.0  18.0  13.0
# ...

# %%
ram_index = [2] * len(df_final)

df_final[5] / df_final[]
# Out:
#                                                                                                     5  \
# C1-MD1rIba1-2_9_3_2.28MIP_Simple Segmentation-1...  [376. 355. 377. 350. 377. 356. 378. 349. 378. ...
# C1-MD1rIba1-2_9_1_2.52MIP_Simple Segmentation-1...  [365. 343. 365. 344. 366. 345. 367. 346. 368. ...
# .DS_Store                                           [365. 343. 365. 344. 366. 345. 367. 346. 368. ...
# C1-MD1rIba1-2_7_4_2.28MIP_Simple Segmentation-1...  [348. 389. 349. 389. 350. 380. 350. 388. 351. ...
# C1-MD1rIba1-2_15_2_2.28MIP_Simple Segmentation-...  [395. 351. 395. 352. 395. 353. 395. 354. 395. ...
# C1-MD1rIba1-2_5_3_2.28MIP_Simple Segmentation-1...  [324. 351. 325. 352. 326. 352. 327. 352. 328. ...
# C1-MD1rIba1-2_5_4_2.28MIP_Simple Segmentation-2...  [249. 361. 250. 361. 251. 361. 252. 361. 253. ...
# C1-MD1rIba1-2_26_4_2.28MIP_Simple Segmentation-...  [365. 392. 366. 391. 367. 390. 369. 399. 370. ...
# ...
